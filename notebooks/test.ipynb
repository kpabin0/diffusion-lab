# %%
import torch
import seaborn as sns

from diflab.utils import customProb2D

# %%
loc = torch.tensor([0.0, 0.0])
scale = torch.tensor([1.0, 1.0])
prob = customProb2D(loc, scale)
x = prob.sample(1000)

# %%
sns.kdeplot(x=x[:, 0], y=x[:,1], fill=True, levels=5)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
import torch
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(2, 20),
    nn.ReLU(),
    nn.Linear(20, 100),
    nn.ReLU(),
    nn.Linear(100, 20),
    nn.ReLU(),
    nn.Linear(20, 2)
)

# %%
def loss_fn(model, )

# %%
for n in
